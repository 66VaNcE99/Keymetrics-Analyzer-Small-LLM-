# %% [markdown]
# ## EXTRACTED METRICS (UK Peat)(english):
#
# # Page 5 | nearly 7,000 square kilometres | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 6 | peatland restoration | Action | Area | confidence=0.9 | FP=False | FN=False (right class: policy action)
# # Page 7 | 35,000 ha of peatland restoration by 2025 | Action | Area | confidence=0.9 | FP=False | FN=False(right label: outcome| area)
# # Page 8 | 35,000 hectares of peatland | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 8 | creating or restoring 500,000 hectares of wildlife rich habitat | Action | Area | confidence=0.9 | FP=False | FN=False (right label: outcome|practical resource)
# # Page 8 | greenhouse gas emissions from natural resources | Outcome | Emissions | confidence=0.8 | FP=False | FN=False
# # Page 9 | are approximately 1,420,000 hectares of peatland in England | Action | Area | confidence=0.9 | FP=False | FN=False ((FP: True))
# # Page 10 | 30 cm peat layer stores at least the same amount of carbon as tropical rain forest over an equivalent area | Outcome | Emissions | confidence=0.9 | FP=False | FN=False (right label: outcome|knowledge)
# # Page 10 | 10 million tonnes carbon dioxide equivalent per year | Outcome | Emissions | confidence=0.9 | FP=False | FN=False
# # Page 10 | 7 ,8 Healthy peatlands have a net cooling effect on the climate, contributing to the government’s target to achieve Net Zero by 2050. | Outcome | Emissions | confidence=0.9 | FP=False | FN=False
# # Page 10 | Nearly a third of our deep peat is protected as Sites of Special Scientific Interest. | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 10 | degraded peatland releases dissolved organic carbon into the water | Action | Emissions | confidence=0.8 | FP=False | FN=False
# # Page 10 | hydrology | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 11 | declining water quality | Outcome | Emissions | confidence=0.8 | FP=False | FN=False
# # Page 13 | restoration of their peatland | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 13 | 35,000 hectares | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 17 | majority of greenhouse gas emissions from our peatlands come from the | Outcome | Emissions | confidence=0.9 | FP=False | FN=False
# # Page 23 | 151.20 hectares | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 24 | 87,000 hectares | Action | Area | confidence=0.9 | FP=False | FN=False (Area or site status?)
# # Page 24 | Land with a gradient of over 35 degrees is exempt from the need for a licence. | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 24 | 142,000 hectares | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 24 | 1,800 hectares | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 24 | 00 hectares | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 27 | with deep peat protected sites over the past decade | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 36 | Make more robust estimates of greenhouse gas emissions from peatlands | Outcome | Emissions | confidence=0.9 | FP=False | FN=False

# %% [markdown]
# ## EXTRACTED METRICS (margade)(estonian):
#
# # Page 1 | WET FOREST HABITAT TYPES (*9080, *91D0, *91E0, 91F0) | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 2 | *9080, *91D0, *91E0, 91F0 | Unsure | Area | confidence=0.0 | FP=False | FN=False
# # Page 2 | Total area | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 2 | impact on the carbon balance | Outcome | Emissions | confidence=0.8 | FP=False | FN=False
# # Page 2 | Destruction of peat deposits in long-term drainage areas | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 3 | Appendix 4. Overview maps of the primary areas to be restored | Action | Area | confidence=0.0 | FP=False | FN=False
# # Page 3 | Appendix 6. Definition of areal protection objectives | Unsure | Area | confidence=0.0 | FP=False | FN=False
# # Page 3 | Appendix 7. Projected additional forest | Outcome | Area | confidence=0.0 | FP=False | FN=False
# # Page 4 | 11,500 hectares | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 4 | 55,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 4 | 63,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 5 | 6,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 5 | 2,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 5 | ha of the habitat type riparian mixed forests of Quercus robur, Ulmus laevis and Ulmus minor, Fraxinus excelsior or    Fraxinus angustifolia, along the great rivers (Ulmenion minoris) | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 5 | 16.8 million euros | Unsure | Miscellaneous | confidence=0.9 | FP=True | FN=False (FP?)
# # Page 7 | at least 0.1 hectare | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 7 | forests (forested wetlands). In this action plan, the Nature Directive | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 7 | forested wetlands | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 7 | Soovikumet - wet forest with a peaty humus horizon (less than 30 cm of peat) | Outcome | Area | confidence=0.9 | FP=False | FN=False
# # Page 9 | wet forest habitat types | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 10 | distribution, condition, and protection of Estonian wet forests | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 10 | implemented active restoration measures on 10,500 hectares of state land | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 10 | at least 55,000 ha of swampy and swamp-deciduous forests (*9080) have been preserved | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 10 | at least 63,000 ha of habitat type transitional swamp and bog forests (*91D0) have been preserved | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 10 | lowland forests (*91E0) have preserved at least 6000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 10 | habitat type broad-leaved floodplain forests (91F0) have been preserved for at least 2000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 10 | allocated 16.8 million euros. | Unsure | Miscellaneous | confidence=1.0 | FP=False | FN=False
# # Page 11 | Legally protect at least 30% of EU land and 30% of EU marine areas | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 11 | restore flooding in floodplain forests | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 12 | old natural forests (*9010) | Unsure | Area | confidence=0.8 | FP=False | FN=False
# # Page 13 | Lowland bog, lodu, eel wax, oja, transitional bog, sedge, bear moss, blueberry Swamp, transitional swamp, bruise, lowland, thistle, sedge, gooseberry Lowland, bog, eelgrass | Outcome | Area | confidence=0.9 | FP=False | FN=False
# # Page 13 | *91E0 | Action | Area | confidence=0.0 | FP=False | FN=False
# # Page 13 | *9080 | Action | Area | confidence=0.0 | FP=False | FN=False
# # Page 14 | over 0.3 | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 14 | over four meters | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 15 | a) the forest grows on undrained nutrient-poor peat, where the peat | Outcome | Area | confidence=0.9 | FP=False | FN=False
# # Page 18 | 998,600 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 18 | 85,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 18 | 7000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 18 | 2,562 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 18 | Total swamp forests 358.4 15.4 3.8 | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 22 | 118,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 22 | Target protection zone and reserve total* 29,775 42,015 4,001,571 | Unsure | Area | confidence=0.9 | FP=False | FN=False
# # Page 23 | the sum of the areas in the cells of the expected target protection zones | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 23 | 23,710 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 23 | 16,639 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 23 | carbon stock prepared during the mapping and evaluation ELME project is based on the map layers inventory of different communities of wet forests | Outcome | Emissions | confidence=0.9 | FP=False | FN=False
# # Page 23 | nutrient-poor drained swamp forests emitted an average of 269 g/m2 of carbon dioxide per year | Outcome | Emissions | confidence=0.9 | FP=False | FN=False
# # Page 25 | drainage of wet forests | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 27 | 9080 and 91E0 forests mostly kasiks | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 27 | area related to changes (Palo and Remm 2019) | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 28 | 2,300 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 28 | forest areas | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 28 | 7,500 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 28 | Läänem was restored | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 28 | 3300 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 31 | a large area has been made in recent years | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 31 | Effect of ditch network maintenance and renewal on wet LD | Outcome | Emissions | confidence=0.0 | FP=False | FN=False
# # Page 32 | restoration area | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 32 | the change of the total area of wet forests by types of forest habitat | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 32 | size of monitoring areas | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 32 | distant drainage effects | Outcome | Emissions | confidence=0.9 | FP=False | FN=False
# # Page 33 | 3589 ha | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 37 | in restricted zones and storage areas is allowed exceptionally | Action | Area | confidence=0.0 | FP=False | FN=False
# # Page 37 | therefore, over time, the water cycle and moisture regime of the entire ecosystem changes, and the area may cease to function as a groove | Outcome | Area | confidence=0.9 | FP=False | FN=False
# # Page 37 | thick peat soils (peat layer thickness over 1 m) | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 38 | The effects of long-term drainage are increasing. | Outcome | Emissions | confidence=0.8 | FP=False | FN=False
# # Page 39 | thick peat soils (peat layer thickness over 1 m) | Outcome | Area | confidence=0.9 | FP=False | FN=False
# # Page 39 | thickness over 1 m) are the largest carbon storage sites on land | Outcome | Emissions | confidence=0.9 | FP=False | FN=False
# # Page 39 | Output of nitrogen, phosphorus and total organic carbon (TOC) increases in the outflow (Finer et al. 2021) | Outcome | Emissions | confidence=0.9 | FP=False | FN=False
# # Page 39 | limit land improvement works in areas with thick (>1 m) peat deposits | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 40 | Nutrient-rich thin peat bog forests (part of type *9080) become secondary as desired or grove forests. | Unsure | Area | confidence=0.9 | FP=False | FN=False
# # Page 40 | therefore, over time, the water cycle and moisture regime of the entire ecosystem changes, and the area may cease to function as a groove | Outcome | Area | confidence=0.8 | FP=False | FN=False
# # Page 40 | Mainly those with little or no drainage effect | Outcome | Emissions | confidence=0.9 | FP=False | FN=False
# # Page 41 | 5. Mainly state forests with little or no drainage effect located outside protected areas | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 41 | remote effects extensiveness, especially in lower reaches and areas surrounded by drainage systems | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 43 | 3. Mainly those with little or no drainage effect located outside protected areas | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 45 | IMPACT OF SURROUNDING LAND USE (EXCLUDING DRAINAGE SYSTEMS) | Outcome | Area | confidence=0.0 | FP=False | FN=False
# # Page 46 | protected areas | Unsure | Area | confidence=0.9 | FP=False | FN=False
# # Page 46 | the effect of long-term subsidence is strongest on lowlands and weakest on bogs | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 47 | Wet storage of CO2 is important for climate change mitigation | Outcome | Emissions | confidence=0.8 | FP=False | FN=False
# # Page 47 | important CO2 storage in wet forests | Outcome | Emissions | confidence=0.8 | FP=False | FN=False
# # Page 47 | important CO2 storage in wet forests | Outcome | Emissions | confidence=0.8 | FP=False | FN=False
# # Page 47 | easily accessible places (e.g. riverside forests) and in popular recreation areas | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 49 | climate change average/unknown unknown unknown unknown PJ01; PJ03 | Outcome | Emissions | confidence=0.8 | FP=False | FN=False
# # Page 50 | The total area and quality of wet forest habitat types in the country is at least at the same level than in 2004 | Outcome | Area | confidence=0.9 | FP=False | FN=False
# # Page 50 | swamp and swamp-deciduous forests (*9080), at least 5000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 50 | swamp and bog forests (*91D0), at least 5000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 50 | floodplain forests (*91E0), at least 500 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 50 | areas with regeneration potential delimited (both habitat type and areas with recovery potential total 1000 ha) | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 50 | league areas total 1000 ha) | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 51 | The total area accumulating peat in forests has not decreased compared to 2004 and in protected forests, this area has increased. | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 51 | 55,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 51 | defense status improved on 16,000 hectares. | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 51 | 6,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 51 | areas of at least 2000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 52 | 2027. by the year 3,500 ha of designated forests | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 52 | 5248 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 52 | 5248 ha. | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 53 | 440 | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 53 | area 440 | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 53 | Soomaa 2 Soomaa | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 53 | nature reserve | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 53 | nature reserve Tudusoo bird and nature area 593 | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 53 | Mustasaare Alutaguse | Unsure | Miscellaneous | confidence=0.5 | FP=True | FN=False
# # Page 53 | national park Muraka bird and nature area 236 | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 53 | national park S | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 53 | locations and impact assessments are provided in the restoration project of a specific restoration area. | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 54 | It is a comprehensive plan that summarizes the existing Natura areas the protection goals set in the protection management plans and specifies area-based protection measures | Outcome | Area | confidence=0.9 | FP=False | FN=False
# # Page 54 | area-based conservation objectives | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 56 | into transitional swamp and bog forests | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 57 | For example, Öörti bog in the old days measurements made in transitional swamp forests showed that the breast area of the stand is 13–21 m2/ha, but there were also wetter places where the chest area did not exceed 10 m2/ha. | Outcome | Area | confidence=0.9 | FP=False | FN=False
# # Page 57 | thicknes of the peat layer | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 59 | 55,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 59 | ca. 18,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 61 | draining effect on wet forest habitat types | Outcome | Emissions | confidence=0.9 | FP=False | FN=False
# # Page 62 | 3,500 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 62 | The condition of 10,500 ha of wet forest habitat types | Outcome | Area | confidence=0.9 | FP=False | FN=False
# # Page 62 | 500 ha of rehabilitated areas must be acquired for the state | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 64 | Emissions of methane from northern peatlands: a review of management impacts and implications for future management options | Outcome | Emissions | confidence=0.8 | FP=False | FN=False
# # Page 64 | Annual gaseous carbon budgets of forest-to-bog restoration sites are strongly determined by vegetation composition | Outcome | Emissions | confidence=0.9 | FP=False | FN=False
# # Page 65 | The climate warming effect of a fen peat meadow with fluctuating water table is reduced by young alder trees. | Outcome | Emissions | confidence=0.9 | FP=False | FN=False
# # Page 65 | drained organic forest soils | Action | Emissions | confidence=0.9 | FP=False | FN=False
# # Page 65 | Kaitstavate soode tegevuskava | Action | Area | confidence=0.0 | FP=False | FN=False
# # Page 66 | historical formation of the Natura 2000 areas | Outcome | Area | confidence=0.9 | FP=False | FN=False
# # Page 67 | Greenhouse gas flux measurements in a forestry-drained peatland indicate a large carbon sink. | Outcome | Emissions | confidence=0.9 | FP=False | FN=False
# # Page 67 | sisuaruanne | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 69 | drainage | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 70 | Restoring functional forested peatlands | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 75 | the entire area of lowland and floodplain soils was taken from the soil map and 25 m was created for them external buffer | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 75 | 72,522 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 75 | 2,316 polygons and a total area of 72,522 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 76 | 50–1000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 77 | area of habitats in poor condition (condition II-III) (+) (0 ha 0; 1–29 ha +1; 30–99 ha +2; 100-199 ha +3; ≥200 ha +4) | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 77 | A total of 55 areas (with a total area of ​​15,500 ha) remained in the selection at this stage. | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 77 | At this stage, the past of the areas was also taken into account, using the historical maps of the Land Board. | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 78 | 5) Tudusoo (No. 13). Argument: synergy with previous gender restoration areas. | Unsure | Area | confidence=0.9 | FP=False | FN=False
# # Page 78 | The area of Mustassaare (no. 2) is related to the Muraka complex and RMK once had it restoration to talk. | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 78 | currently delimited to the south of the land area are in the target protection zone | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 78 | 9) The area of Pihla-Kaibaldi (no. 25) is also on the list of open marsh restoration areas | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 79 | sluice and possible specification of the boundaries of restoration areas | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 79 | state land | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 79 | The W part of Endla (no. 52) is a classic wetland and needs to be restored. | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 79 | 13) Käntu-Kastja (no. 41) is a storage area with a lot of private land | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 80 | 7,700 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 87 | 86 Ohepalu restoration area | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 91 | Area inflows and outflows are needed both before and after restoration activities | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 92 | AREAL CONSERVATION OBJECTIVES FOR WET FOREST HABITAT TYPES WERE DERIVED FROM THEIR ECOSSYSTEMS OF THE THREE MAIN GOALS SET TO ACHIEVE A FAVORABLE STATE UNTIL 2050: 1) FAVORABLE CONDITION LD | Outcome | Area | confidence=0.9 | FP=False | FN=False
# # Page 92 | preservation of the peat-accumulating forest area at least in 2004 | Unsure | Area | confidence=0.8 | FP=False | FN=False
# # Page 92 | areal target levels | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 92 | 90,000 ha | Outcome | Area | confidence=0.9 | FP=False | FN=False
# # Page 92 | 90,000 ha (LD monitoring report1) up to 135,000 ha (environmental register2; SMI3; of which 77,000 ha under strict protection) | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 92 | compensating degraded areas | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 93 | washing point on the land area of Estonia (representing the size of 4,346,619 ha area). Each random point is matched on the relevant map layers and the result is points the proportion multiplied by the represented area. | Action | Area | confidence=0.0 | FP=False | FN=False
# # Page 93 | is the estimation range with 95% confidence limits of 8259–9128 ha | Outcome | Area | confidence=0.95 | FP=False | FN=False
# # Page 93 | 9080 – 53 516 ha (actual: 50243 ha) | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 93 | 50243 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 93 | 63 491 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 93 | 4157 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 93 | 717 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 93 | Estonian forest register (KAUR, 10.01.2022) | Unsure | Area | confidence=0.9 | FP=False | FN=False
# # Page 95 | 9450 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 95 | 3216 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 95 | 3642 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 95 | 7607 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 95 | 1600 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 95 | 2478 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 95 | at least 15,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 95 | at least 10,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 95 | 19,447 ha in strictly protected areas | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 95 | 4190 ha will be added to it and 3573 ha from restricted zones | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 95 | 2000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 95 | 30,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 95 | 25,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 95 | the official area of *91E0 is distributed between different inquiries (Section 3.2) and mostly (78%) remains out of them altogether | Action | Area | confidence=0.0 | FP=False | FN=False
# # Page 96 | at least 1000 ha in current and planned strict conservation areas | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 96 | 9080 – 12,562 ha (incl. 5005 ha of state land) and *91D0 – 5877 ha (including 4353 ha of state land) | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 96 | 1200 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 97 | 35,000 - 40,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 97 | 500,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 97 | 10,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 97 | 55,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 97 | 120,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 97 | 25,000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 97 | 2050 goal at the level of 70,000 ha | Unsure | Area | confidence=0.9 | FP=False | FN=False
# # Page 97 | 63,491 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 97 | 3800 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 98 | 22,400 hectares | Action | Area | confidence=0.8 | FP=False | FN=False
# # Page 98 | 2050 target should definitely not be below 6000 ha | Outcome | Area | confidence=0.9 | FP=False | FN=False
# # Page 98 | less than 6000 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 98 | 700 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 98 | 717 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 98 | 1500 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 98 | 1930 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 98 | increase the area of 91F0, according to an expert estimate of 1300 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 98 | Nanguna 1300 ha | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 98 | The total area of ​​all Estonian nature areas listed in the standard database. | Outcome | Area | confidence=0.9 | FP=False | FN=False
# # Page 98 | Analysis of the University of Tartu's random point request for protection of (possible) areas of wet forest habitat types | Outcome | Area | confidence=0.0 | FP=False | FN=False
# # Page 99 | Areas of areas to be restored resulting from protection goals (ha) as of March 2024 | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 99 | the area that must be restored by the year 2050 | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 99 | The column shows the area that needs to be restored by the year 2030 | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 100 | Size to be analyzed | Action | Area | confidence=0.9 | FP=False | FN=False
# # Page 100 | 5862 3016 3344 11 034 242 15 | Action | Area | confidence=0.9 | FP=False | FN=False
